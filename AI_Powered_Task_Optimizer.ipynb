# %% [markdown]
# <a href="https://colab.research.google.com/github/Asifpatan05/Zidio-AI-Powered-Task-Optimizer/blob/main/AI_Powered_Task_Optimizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import datetime, timedelta
import random

# %%
# Sample task data generation
titles = ["Write report", "Study for test", "Finish project", "Team meeting", "Reply to emails", "Code review"]
priorities = ["High", "Medium", "Low"]
data = []

# %%
for i in range(20):
    task = {
        "Title": random.choice(titles),
        "Description": "Some task details",
        "Deadline": (datetime.now() + timedelta(days=random.randint(1, 10))).strftime('%Y-%m-%d'),
        "Estimated_Duration_Hrs": random.randint(1, 8),
        "User_Priority": random.choice(priorities)
    }
    data.append(task)

# %%
df = pd.DataFrame(data)
df.to_csv("task_data.csv", index=False)
print("Generated synthetic task data.")
# Out:
# Generated synthetic task data.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from datetime import datetime

# %%
# Load data
data = pd.read_csv("task_data.csv")

# %%
# Feature engineering
data["Deadline"] = pd.to_datetime(data["Deadline"])
data["Days_Left"] = (data["Deadline"] - datetime.now()).dt.days
data["Duration_Category"] = pd.cut(data["Estimated_Duration_Hrs"], bins=[0, 2, 5, 10], labels=[0, 1, 2])

# %%
# Encode labels
le = LabelEncoder()
data["Priority_Label"] = le.fit_transform(data["User_Priority"])

# %%
# Define features and target
X = data[["Days_Left", "Estimated_Duration_Hrs"]]
y = data["Priority_Label"]

# %%
# Train/test split — now should work!
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Train model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predict
data["Predicted_Priority_Label"] = model.predict(X)
data["Predicted_Priority"] = le.inverse_transform(data["Predicted_Priority_Label"])

# %%
print(data[["Title", "Predicted_Priority"]])
# Out:
#               Title Predicted_Priority
# 0      Team meeting               High
# 1   Reply to emails             Medium
# 2    Study for test                Low
# 3      Write report                Low
# 4       Code review               High
# 5      Team meeting             Medium
# 6      Team meeting             Medium
# 7      Write report             Medium
# 8   Reply to emails             Medium
# 9      Write report             Medium
# 10   Study for test               High
# 11  Reply to emails                Low
# 12   Study for test                Low
# 13  Reply to emails               High
# 14   Study for test                Low
# 15      Code review                Low
# 16      Code review                Low
# 17     Write report               High
# 18   Finish project               High
# 19   Finish project             Medium
